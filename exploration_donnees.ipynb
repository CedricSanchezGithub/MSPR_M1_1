# %% [markdown]
# # Exploration des données — Electio-Analytics
#
# Notebook d'exploration de la base SQLite `electio_herault.db`.
# Données filtrées pour le département de l'Hérault (34), 341 communes.
#
# **Prérequis** : avoir exécuté le pipeline ETL (`python main.py etl`) pour générer la base.

# %%
import sqlite3
import pandas as pd

DB_PATH = "data/output/electio_herault.db"
conn = sqlite3.connect(DB_PATH)
print(f"Connecté à {DB_PATH}")
# Out:
# Connecté à data/output/electio_herault.db

# %% [markdown]
# ## 1. Vue d'ensemble de la base
#
# 12 tables, toutes liées par `codgeo` (code INSEE commune).

# %%
# Lister toutes les tables et leur nombre de lignes
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name", conn)

print(f"{'Table':<25s} {'Lignes':>8s}")
print("-" * 35)
for table in tables['name']:
    count = pd.read_sql(f"SELECT COUNT(*) as nb FROM {table}", conn)['nb'][0]
    print(f"  {table:<23s} {count:>8,}")
# Out:
# Table                       Lignes
# -----------------------------------
#   catnat                     4,130
#   communes                     341
#   comptes_communes           5,477
#   csp                        3,087
#   csp_diplome                2,744
#   diplomes                     341
#   elections                 19,596
#   naissances_deces           5,797
#   population                12,617
#   revenus                      342
#   risques                    3,184
#   secteurs_activite          3,087

# %% [markdown]
# ## 2. Communes (table de référence)
#
# Table pivot du modèle : chaque commune a un `codgeo` unique (code INSEE 5 caractères).

# %%
communes = pd.read_sql("SELECT * FROM communes", conn)
print(f"Nombre de communes : {len(communes)}")
print(f"Colonnes : {list(communes.columns)}")
communes.sample(10)
# Out:
# Nombre de communes : 341
# Colonnes : ['codgeo', 'nom', 'departement']
#     codgeo                       nom departement
# 317  34320               Vailhauquès          34
# 296  34299                  Sérignan          34
# 290  34293     La Salvetat-sur-Agout          34
# 209  34211         Le Poujol-sur-Orb          34
# 276  34279  Saint-Nazaire-de-Ladarez          34
# 142  34144        Lunas-les-Châteaux          34
# 339  34343             Viols-le-Fort          34
# 300  34303                     Sorbs          34
# 99   34101                 Florensac          34
# 91   34092                     Cruzy          34

# %% [markdown]
# ## 3. Élections municipales
#
# Résultats par candidat, par commune, pour les municipales 2008, 2014, 2020.
# Chaque candidat est classé `Gauche` ou `Droite` (colonne `camp`).

# %%
elections = pd.read_sql("SELECT * FROM elections", conn)
print(f"Lignes : {len(elections):,}")
print(f"Années : {sorted(elections['annee'].unique())}")
print(f"Tours : {sorted(elections['tour'].unique())}")
print(f"\nRépartition par camp :")
print(elections['camp'].value_counts())
elections.head()
# Out:
# Lignes : 19,596
# Années : [np.int64(2008), np.int64(2014), np.int64(2020)]
# Tours : [np.int64(1), np.int64(2)]
#
# Répartition par camp :
# camp
# Droite    13801
# Gauche     5795
# Name: count, dtype: int64
#   codgeo  annee  tour nom_candidat prenom_candidat nuance  voix  \
# 0  34003   2020     2       COUSIN      Jean Louis    LRN    46
# 1  34003   2020     2       COUSIN      Jean Louis    LRN    34
# 2  34003   2020     2       COUSIN      Jean Louis    LRN    57
# 3  34003   2020     2       COUSIN      Jean Louis    LRN    33
# 4  34003   2020     2       COUSIN      Jean Louis    LRN    29
#
#    pct_voix_inscrits  pct_voix_exprimes    camp
# 0               3.61               7.07  Droite
# 1               3.36               8.56  Droite
# 2               5.30              11.88  Droite
# 3               3.36               7.86  Droite
# 4               3.21               6.02  Droite

# %%
# Répartition des voix par année et camp (T1 uniquement)
t1 = elections[elections['tour'] == 1]
pivot = t1.groupby(['annee', 'camp'])['voix'].sum().unstack(fill_value=0)
pivot['total'] = pivot.sum(axis=1)
pivot['pct_gauche'] = (100 * pivot.get('Gauche', 0) / pivot['total']).round(1)
pivot
# Out:
# camp   Droite  Gauche   total  pct_gauche
# annee
# 2008   185417  131460  316877        41.5
# 2014   765028  191801  956829        20.0
# 2020   631540  101998  733538        13.9

# %% [markdown]
# ## 4. Population
#
# Population municipale par commune et par année de recensement (1968 à 2022).

# %%
population = pd.read_sql("SELECT * FROM population", conn)
print(f"Lignes : {len(population):,}")
print(f"Années disponibles : {sorted(population['annee'].unique())}")
print(f"\nStatistiques sur la population :")
population['population'].describe().round(0)
# Out:
# Lignes : 12,617
# Années disponibles : [np.int64(1876), np.int64(1881), np.int64(1886), np.int64(1891), np.int64(1896), np.int64(1901), np.int64(1906), np.int64(1911), np.int64(1921), np.int64(1926), np.int64(1931), np.int64(1936), np.int64(1954), np.int64(1962), np.int64(1968), np.int64(1975), np.int64(1982), np.int64(1990), np.int64(1999), np.int64(2006), np.int64(2007), np.int64(2008), np.int64(2009), np.int64(2010), np.int64(2011), np.int64(2012), np.int64(2013), np.int64(2014), np.int64(2015), np.int64(2016), np.int64(2017), np.int64(2018), np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022), np.int64(2023)]
#
# Statistiques sur la population :
# count     12617.0
# mean       2406.0
# std       12483.0
# min           5.0
# 25%         255.0
# 50%         622.0
# 75%        1719.0
# max      310240.0
# Name: population, dtype: float64

# %%
# Top 10 communes les plus peuplées (dernière année disponible)
derniere_annee = population['annee'].max()
top_pop = population[population['annee'] == derniere_annee].nlargest(10, 'population')
top_pop = top_pop.merge(communes[['codgeo', 'nom']], on='codgeo', how='left')
print(f"Top 10 communes en {derniere_annee} :")
top_pop[['nom', 'codgeo', 'population']]
# Out:
# Top 10 communes en 2023 :
#                 nom codgeo  population
# 0       Montpellier  34172      310240
# 1           Béziers  34032       81545
# 2              Sète  34301       45337
# 3              Agde  34003       29939
# 4             Lunel  34145       26623
# 5  Castelnau-le-Lez  34057       26058
# 6        Frontignan  34108       24136
# 7            Lattes  34129       17351
# 8           Mauguio  34154       16522
# 9          Juvignac  34123       14055

# %% [markdown]
# ## 5. Revenus

# %%
revenus = pd.read_sql("SELECT * FROM revenus", conn)
print(f"Lignes : {len(revenus)}")
print(f"Colonnes ({len(revenus.columns)}) :")
for c in revenus.columns:
    print(f"  - {c}")
revenus.head()
# Out:
# Lignes : 342
# Colonnes (55) :
#   - [disp]_nbre_de_menages_fiscaux
#   - [disp]_nbre_de_personnes_dans_les_menages_fiscaux
#   - [disp]_nbre_dunites_de_consommation_dans_les_menages_fiscaux
#   - [disp]_1ᵉʳ_quartile_(€)
#   - [disp]_mediane_(€)
#   - [disp]_3ᵉ_quartile_(€)
#   - [disp]_ecart_interquartile_(€)
#   - [disp]_1ᵉʳ_decile_(€)
#   - [disp]_2ᵉ_decile_(€)
#   - [disp]3ᵉ_decile_(€)
#   - [disp]_4ᵉ_decile_(€)
#   - [disp]_6ᵉ_decile_(€)
#   - [disp]_7ᵉ_decile_(€)
#   - [disp]_8ᵉ_decile_(€)
#   - [disp]_9ᵉ_decile_(€)
#   - [disp]_rapport_interdecile_9ᵉ_decile/1ᵉʳ_decile
#   - [disp]_s80/20
#   - [disp]_iice_de_gini
#   - [disp]_part_des_revenus_d’activite_(%)
#   - [disp]_dont_part_des_salaires_et_traitements(%)
#   - [disp]_dont_part_des_iemnites_de_chômage_(%)
#   - [disp]_dont_part_des_revenus_des_activites_non_salariees_(%)
#   - [disp]_part_des_pensions,_retraites_et_rentes_(%)
#   - [disp]_part_des_revenus_du_patrimoine_et_autres_revenus_(%)
#   - [disp]_part_de_lensemble_des_prestations_sociales_(%)
#   - [disp]_dont_part_des_prestations_familiales_(%)
#   - [disp]_dont_part_des_minima_sociaux_(%)
#   - [disp]_dont_part_des_prestations_logement_(%)
#   - [disp]_part_des_impôts_(%)
#   - [dec]_nbre_de_menages_fiscaux
#   - [dec]_nbre_de_personnes_dans_les_menages_fiscaux
#   - [dec]_nbre_dunites_de_consommation_dans_les_menages_fiscaux
#   - [dec]_part_des_menages_fiscaux_imposes_(%)
#   - [dec]_1ᵉʳ_quartile_(€)
#   - [dec]_mediane_(€)
#   - [dec]_3ᵉ_quartile_(€)
#   - [dec]_ecart_interquartile_(€)
#   - [dec]_1ᵉʳ_decile_(€)
#   - [dec]_2ᵉ_decile_(€)
#   - [dec]_3ᵉ_decile__(€)
#   - [dec]_4ᵉ_decile_(€)
#   - [dec]_6ᵉ_decile_(€)
#   - [dec]_7ᵉ_decile_(€)
#   - [dec]_8ᵉ_decile_(€)
#   - [dec]_9ᵉ_decile_(€)
#   - [dec]_rapport_interdecile_d9/d1
#   - [dec]_s80/s20
#   - [dec]_iice_de_gini
#   - [dec]_part_des_revenus_d’activite_(%)
#   - [dec]_dont_part_des_salaires_et_traitements_(%)
#   - [dec]_dont_part_des_iemnites_de_chômage_(%)
#   - [dec]_dont_part_des_revenus_des_activites_non_salariees_(%)
#   - [dec]_part_des_pensions,_retraites_et_rentes_(%)
#   - [dec]_part_des_autres_revenus_(%)
#   - codgeo
#    [disp]_nbre_de_menages_fiscaux  \
# 0                           771.0
# 1                           566.0
# 2                         16947.0
# 3                           117.0
# 4                           124.0
#
#    [disp]_nbre_de_personnes_dans_les_menages_fiscaux  \
# 0                                             1848.0
# 1                                             1348.0
# 2                                            31298.0
# 3                                              233.0
# 4                                              281.0
#
#    [disp]_nbre_dunites_de_consommation_dans_les_menages_fiscaux  \
# 0                                             1244.1
# 1                                              902.8
# 2                                            23442.4
# 3                                              171.1
# 4                                              191.8
#
#    [disp]_1ᵉʳ_quartile_(€)  [disp]_mediane_(€)  [disp]_3ᵉ_quartile_(€)  \
# 0                      NaN             21720.0                     NaN
# 1                      NaN             21060.0                     NaN
# 2                  14570.0             20410.0                 27350.0
# 3                      NaN             18830.0                     NaN
# 4                      NaN             23490.0                     NaN
#
#    [disp]_ecart_interquartile_(€)  [disp]_1ᵉʳ_decile_(€)  \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                         12780.0                10510.0
# 3                             NaN                    NaN
# 4                             NaN                    NaN
#
#    [disp]_2ᵉ_decile_(€)  [disp]3ᵉ_decile_(€)  ...  \
# 0                   NaN                  NaN  ...
# 1                   NaN                  NaN  ...
# 2               13370.0              15710.0  ...
# 3                   NaN                  NaN  ...
# 4                   NaN                  NaN  ...
#
#    [dec]_rapport_interdecile_d9/d1  [dec]_s80/s20  [dec]_iice_de_gini  \
# 0                             None            NaN                 NaN
# 1                             None            NaN                 NaN
# 2                              8,0           10.7               0.389
# 3                             None            NaN                 NaN
# 4                             None            NaN                 NaN
#
#    [dec]_part_des_revenus_d’activite_(%)  \
# 0                                    NaN
# 1                                    NaN
# 2                                   46.5
# 3                                    NaN
# 4                                    NaN
#
#    [dec]_dont_part_des_salaires_et_traitements_(%)  \
# 0                                              NaN
# 1                                              NaN
# 2                                             36.9
# 3                                              NaN
# 4                                              NaN
#
#    [dec]_dont_part_des_iemnites_de_chômage_(%)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          4.2
# 3                                          NaN
# 4                                          NaN
#
#    [dec]_dont_part_des_revenus_des_activites_non_salariees_(%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                5.4
# 3                                                NaN
# 4                                                NaN
#
#    [dec]_part_des_pensions,_retraites_et_rentes_(%)  \
# 0                                               NaN
# 1                                               NaN
# 2                                              44.0
# 3                                               NaN
# 4                                               NaN
#
#    [dec]_part_des_autres_revenus_(%)  codgeo
# 0                                NaN   34001
# 1                                NaN   34002
# 2                                9.5   34003
# 3                                NaN   34004
# 4                                NaN   34005
#
# [5 rows x 55 columns]

# %% [markdown]
# ## 6. CSP (Catégories socio-professionnelles)
#
# Actifs de 25-54 ans par catégorie (cadres, ouvriers, employés, etc.) et par année de recensement.

# %%
csp = pd.read_sql("SELECT * FROM csp", conn)
print(f"Lignes : {len(csp)}")
print(f"Années RP : {sorted(csp['annee'].unique())}")
print(f"\nColonnes ({len(csp.columns)}) :")
for c in csp.columns[:15]:
    print(f"  - {c}")
if len(csp.columns) > 15:
    print(f"  ... et {len(csp.columns) - 15} autres")
# Out:
# Lignes : 3087
# Années RP : [np.int64(1968), np.int64(1975), np.int64(1982), np.int64(1990), np.int64(1999), np.int64(2006), np.int64(2011), np.int64(2016), np.int64(2022)]
#
# Colonnes (110) :
#   - agriculteurs
# actifs_ayant_un_emploi
# rp1968
#   - agriculteurs
# chômeurs
# rp1968
#   - artisans,_commerçants,_chefs_d'entreprise
# actifs_ayant_un_emploi
# rp1968
#   - artisans,_commerçants,_chefs_d'entreprise
# chômeurs
# rp1968
#   - cadres_et_professions_intellectuelles_supérieures
# actifs_ayant_un_emploi
# rp1968
#   - cadres_et_professions_intellectuelles_supérieures
# chômeurs
# rp1968
#   - professions_intermédiaires
# actifs_ayant_un_emploi
# rp1968
#   - professions_intermédiaires
# chômeurs
# rp1968
#   - employés
# actifs_ayant_un_emploi
# rp1968
#   - employés
# chômeurs
# rp1968
#   - ouvriers
# actifs_ayant_un_emploi
# rp1968
#   - ouvriers
# chômeurs
# rp1968
#   - codgeo
#   - annee
#   - agriculteurs
# actifs_ayant_un_emploi
# rp1975
#   ... et 95 autres

# %% [markdown]
# ## 7. Diplômes
#
# Niveau de diplôme de la population de 15 ans et plus, par commune.
# Préfixes : `p11` (RP 2011), `p16` (RP 2016), `p22` (RP 2022).

# %%
diplomes = pd.read_sql("SELECT * FROM diplomes", conn)
print(f"Lignes : {len(diplomes)}")
print(f"\nColonnes ({len(diplomes.columns)}) :")
for c in diplomes.columns[:20]:
    print(f"  - {c}")
if len(diplomes.columns) > 20:
    print(f"  ... et {len(diplomes.columns) - 20} autres")
# Out:
# Lignes : 341
#
# Colonnes (190) :
#   - p22_pop0205
#   - p22_pop0610
#   - p22_pop1114
#   - p22_pop1517
#   - p22_pop1824
#   - p22_pop2529
#   - p22_pop30p
#   - p22_scol0205
#   - p22_scol0610
#   - p22_scol1114
#   - p22_scol1517
#   - p22_scol1824
#   - p22_scol2529
#   - p22_scol30p
#   - p22_h0205
#   - p22_h0610
#   - p22_h1114
#   - p22_h1517
#   - p22_h1824
#   - p22_h2529
#   ... et 170 autres

# %% [markdown]
# ## 8. Comptes des communes
#
# Données financières : dette, recettes, dépenses de fonctionnement et d'investissement.

# %%
comptes = pd.read_sql("SELECT * FROM comptes_communes", conn)
print(f"Lignes : {len(comptes)}")
print(f"Années : {sorted(comptes['annee'].unique())}")
print(f"Colonnes : {list(comptes.columns)}")
comptes.describe().round(0)
# Out:
# Lignes : 5477
# Années : [np.int64(2000), np.int64(2001), np.int64(2002), np.int64(2003), np.int64(2004), np.int64(2005), np.int64(2006), np.int64(2007), np.int64(2008), np.int64(2011), np.int64(2012), np.int64(2013), np.int64(2014), np.int64(2015), np.int64(2017), np.int64(2022)]
# Colonnes : ['codgeo', 'annee', 'produits_fonctionnement', 'charges_fonctionnement', 'depenses_personnel', 'depenses_investissement', 'depenses_equipement', 'dette', 'dgf', 'capacite_autofinancement', 'impots_directs', 'impots_indirects']
#         annee  produits_fonctionnement  charges_fonctionnement  \
# count  5477.0                   5477.0                  5477.0
# mean   2009.0                   3496.0                  3053.0
# std       6.0                  17832.0                 15552.0
# min    2000.0                     23.0                    14.0
# 25%    2004.0                    206.0                   173.0
# 50%    2008.0                    583.0                   479.0
# 75%    2014.0                   1864.0                  1590.0
# max    2022.0                 357263.0                319633.0
#
#        depenses_personnel  depenses_investissement  depenses_equipement  \
# count              5477.0                   5477.0               5477.0
# mean               1542.0                   1606.0               1082.0
# std                8292.0                   8320.0               5623.0
# min                  -8.0                      0.0                  0.0
# 25%                  62.0                     92.0                 73.0
# 50%                 206.0                    283.0                226.0
# 75%                 717.0                    917.0                725.0
# max              191165.0                 211991.0             151616.0
#
#           dette      dgf  capacite_autofinancement  impots_directs  \
# count    5477.0   5477.0                    5477.0          5477.0
# mean     2873.0    614.0                     541.0          1618.0
# std     11968.0   3473.0                    3202.0          9288.0
# min         0.0      4.0                   -1404.0            -7.0
# 25%        85.0     49.0                      30.0            60.0
# 50%       370.0    126.0                      85.0           220.0
# 75%      1580.0    367.0                     275.0           758.0
# max    244424.0  75275.0                   72488.0        229135.0
#
#        impots_indirects
# count            5477.0
# mean              306.0
# std              1460.0
# min               -21.0
# 25%                19.0
# 50%                44.0
# 75%               123.0
# max             28182.0

# %% [markdown]
# ## 9. Catastrophes naturelles (CatNat)

# %%
catnat = pd.read_sql("SELECT * FROM catnat", conn)
print(f"Lignes : {len(catnat)}")
print(f"Communes touchées : {catnat['codgeo'].nunique()}")
print(f"Colonnes : {list(catnat.columns)}")

# Top 10 communes les plus touchées
top_cat = catnat.groupby('codgeo').size().sort_values(ascending=False).head(10)
noms = communes.set_index('codgeo')['nom']
top_cat.index = top_cat.index.map(lambda x: f"{noms.get(x, x)} ({x})")
print(f"\nTop 10 communes les plus touchées :")
print(top_cat.to_string())
# Out:
# Lignes : 4130
# Communes touchées : 342
# Colonnes : ['codgeo', 'risque', 'date_debut', 'date_fin', 'date_arrete']
#
# Top 10 communes les plus touchées :
# codgeo
# Montpellier (34172)                 37
# Portiragnes (34209)                 37
# Montarnaud (34163)                  36
# Baillargues (34022)                 34
# Marseillan (34150)                  34
# Béziers (34032)                     32
# Villeneuve-lès-Maguelone (34337)    32
# Clapiers (34077)                    30
# Saint-Gély-du-Fesc (34255)          30
# Saint-Jean-de-Védas (34270)         29

# %% [markdown]
# ## 10. Qualité des données
#
# Vérification des valeurs manquantes et de la couverture par table.

# %%
tables_list = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name", conn)

for table in tables_list['name']:
    df = pd.read_sql(f"SELECT * FROM {table}", conn)
    nulls = df.isnull().sum()
    total_nulls = nulls.sum()
    if total_nulls > 0:
        print(f"\n{table} ({len(df)} lignes) — {total_nulls} valeurs manquantes :")
        for col, n in nulls[nulls > 0].items():
            print(f"  {col}: {n} ({100*n/len(df):.1f}%)")
    else:
        print(f"{table} ({len(df)} lignes) — OK")
# Out:
# catnat (4130 lignes) — OK
# communes (341 lignes) — OK
# comptes_communes (5477 lignes) — OK
#
# csp (3087 lignes) — 296364 valeurs manquantes :
#   agriculteurs
# actifs_ayant_un_emploi
# rp1968: 2744 (88.9%)
#   agriculteurs
# chômeurs
# rp1968: 2744 (88.9%)
#   artisans,_commerçants,_chefs_d'entreprise
# actifs_ayant_un_emploi
# rp1968: 2744 (88.9%)
#   artisans,_commerçants,_chefs_d'entreprise
# chômeurs
# rp1968: 2744 (88.9%)
#   cadres_et_professions_intellectuelles_supérieures
# actifs_ayant_un_emploi
# rp1968: 2744 (88.9%)
#   cadres_et_professions_intellectuelles_supérieures
# chômeurs
# rp1968: 2744 (88.9%)
#   professions_intermédiaires
# actifs_ayant_un_emploi
# rp1968: 2744 (88.9%)
#   professions_intermédiaires
# chômeurs
# rp1968: 2744 (88.9%)
#   employés
# actifs_ayant_un_emploi
# rp1968: 2744 (88.9%)
#   employés
# chômeurs
# rp1968: 2744 (88.9%)
#   ouvriers
# actifs_ayant_un_emploi
# rp1968: 2744 (88.9%)
#   ouvriers
# chômeurs
# rp1968: 2744 (88.9%)
#   agriculteurs
# actifs_ayant_un_emploi
# rp1975: 2744 (88.9%)
#   agriculteurs
# chômeurs
# rp1975: 2744 (88.9%)
#   artisans,_commerçants,_chefs_d'entreprise
# actifs_ayant_un_emploi
# rp1975: 2744 (88.9%)
#   artisans,_commerçants,_chefs_d'entreprise
# chômeurs
# rp1975: 2744 (88.9%)
#   cadres_et_professions_intellectuelles_supérieures
# actifs_ayant_un_emploi
# rp1975: 2744 (88.9%)
#   cadres_et_professions_intellectuelles_supérieures
# chômeurs
# rp1975: 2744 (88.9%)
#   professions_intermédiaires
# actifs_ayant_un_emploi
# rp1975: 2744 (88.9%)
#   professions_intermédiaires
# chômeurs
# rp1975: 2744 (88.9%)
#   employés
# actifs_ayant_un_emploi
# rp1975: 2744 (88.9%)
#   employés
# chômeurs
# rp1975: 2744 (88.9%)
#   ouvriers
# actifs_ayant_un_emploi
# rp1975: 2744 (88.9%)
#   ouvriers
# chômeurs
# rp1975: 2744 (88.9%)
#   agriculteurs
# actifs_ayant_un_emploi
# rp1982: 2744 (88.9%)
#   agriculteurs
# chômeurs
# rp1982: 2744 (88.9%)
#   artisans,_commerçants,_chefs_d'entreprise
# actifs_ayant_un_emploi
# rp1982: 2744 (88.9%)
#   artisans,_commerçants,_chefs_d'entreprise
# chômeurs
# rp1982: 2744 (88.9%)
#   cadres_et_professions_intellectuelles_supérieures
# actifs_ayant_un_emploi
# rp1982: 2744 (88.9%)
#   cadres_et_professions_intellectuelles_supérieures
# chômeurs
# rp1982: 2744 (88.9%)
#   professions_intermédiaires
# actifs_ayant_un_emploi
# rp1982: 2744 (88.9%)
#   professions_intermédiaires
# chômeurs
# rp1982: 2744 (88.9%)
#   employés
# actifs_ayant_un_emploi
# rp1982: 2744 (88.9%)
#   employés
# chômeurs
# rp1982: 2744 (88.9%)
#   ouvriers
# actifs_ayant_un_emploi
# rp1982: 2744 (88.9%)
#   ouvriers
# chômeurs
# rp1982: 2744 (88.9%)
#   agriculteurs
# actifs_ayant_un_emploi
# rp1990: 2744 (88.9%)
#   agriculteurs
# chômeurs
# rp1990: 2744 (88.9%)
#   artisans,_commerçants,_chefs_d'entreprise
# actifs_ayant_un_emploi
# rp1990: 2744 (88.9%)
#   artisans,_commerçants,_chefs_d'entreprise
# chômeurs
# rp1990: 2744 (88.9%)
#   cadres_et_professions_intellectuelles_supérieures
# actifs_ayant_un_emploi
# rp1990: 2744 (88.9%)
#   cadres_et_professions_intellectuelles_supérieures
# chômeurs
# rp1990: 2744 (88.9%)
#   professions_intermédiaires
# actifs_ayant_un_emploi
# rp1990: 2744 (88.9%)
#   professions_intermédiaires
# chômeurs
# rp1990: 2744 (88.9%)
#   employés
# actifs_ayant_un_emploi
# rp1990: 2744 (88.9%)
#   employés
# chômeurs
# rp1990: 2744 (88.9%)
#   ouvriers
# actifs_ayant_un_emploi
# rp1990: 2744 (88.9%)
#   ouvriers
# chômeurs
# rp1990: 2744 (88.9%)
#   agriculteurs
# actifs_ayant_un_emploi
# rp1999: 2744 (88.9%)
#   agriculteurs
# chômeurs
# rp1999: 2744 (88.9%)
#   artisans,_commerçants,_chefs_d'entreprise
# actifs_ayant_un_emploi
# rp1999: 2744 (88.9%)
#   artisans,_commerçants,_chefs_d'entreprise
# chômeurs
# rp1999: 2744 (88.9%)
#   cadres_et_professions_intellectuelles_supérieures
# actifs_ayant_un_emploi
# rp1999: 2744 (88.9%)
#   cadres_et_professions_intellectuelles_supérieures
# chômeurs
# rp1999: 2744 (88.9%)
#   professions_intermédiaires
# actifs_ayant_un_emploi
# rp1999: 2744 (88.9%)
#   professions_intermédiaires
# chômeurs
# rp1999: 2744 (88.9%)
#   employés
# actifs_ayant_un_emploi
# rp1999: 2744 (88.9%)
#   employés
# chômeurs
# rp1999: 2744 (88.9%)
#   ouvriers
# actifs_ayant_un_emploi
# rp1999: 2744 (88.9%)
#   ouvriers
# chômeurs
# rp1999: 2744 (88.9%)
#   agriculteurs
# actifs_ayant_un_emploi
# rp2006: 2744 (88.9%)
#   agriculteurs
# chômeurs
# rp2006: 2744 (88.9%)
#   artisans,_commerçants,_chefs_d'entreprise
# actifs_ayant_un_emploi
# rp2006: 2744 (88.9%)
#   artisans,_commerçants,_chefs_d'entreprise
# chômeurs
# rp2006: 2744 (88.9%)
#   cadres_et_professions_intellectuelles_supérieures
# actifs_ayant_un_emploi
# rp2006: 2744 (88.9%)
#   cadres_et_professions_intellectuelles_supérieures
# chômeurs
# rp2006: 2744 (88.9%)
#   professions_intermédiaires
# actifs_ayant_un_emploi
# rp2006: 2744 (88.9%)
#   professions_intermédiaires
# chômeurs
# rp2006: 2744 (88.9%)
#   employés
# actifs_ayant_un_emploi
# rp2006: 2744 (88.9%)
#   employés
# chômeurs
# rp2006: 2744 (88.9%)
#   ouvriers
# actifs_ayant_un_emploi
# rp2006: 2744 (88.9%)
#   ouvriers
# chômeurs
# rp2006: 2744 (88.9%)
#   agriculteurs
# actifs_ayant_un_emploi
# rp2011: 2744 (88.9%)
#   agriculteurs
# chômeurs
# rp2011: 2744 (88.9%)
#   artisans,_commerçants,_chefs_d'entreprise
# actifs_ayant_un_emploi
# rp2011: 2744 (88.9%)
#   artisans,_commerçants,_chefs_d'entreprise
# chômeurs
# rp2011: 2744 (88.9%)
#   cadres_et_professions_intellectuelles_supérieures
# actifs_ayant_un_emploi
# rp2011: 2744 (88.9%)
#   cadres_et_professions_intellectuelles_supérieures
# chômeurs
# rp2011: 2744 (88.9%)
#   professions_intermédiaires
# actifs_ayant_un_emploi
# rp2011: 2744 (88.9%)
#   professions_intermédiaires
# chômeurs
# rp2011: 2744 (88.9%)
#   employés
# actifs_ayant_un_emploi
# rp2011: 2744 (88.9%)
#   employés
# chômeurs
# rp2011: 2744 (88.9%)
#   ouvriers
# actifs_ayant_un_emploi
# rp2011: 2744 (88.9%)
#   ouvriers
# chômeurs
# rp2011: 2744 (88.9%)
#   agriculteurs
# actifs_ayant_un_emploi
# rp2016: 2744 (88.9%)
#   agriculteurs
# chômeurs
# rp2016: 2744 (88.9%)
#   artisans,_commerçants,_chefs_d'entreprise
# actifs_ayant_un_emploi
# rp2016: 2744 (88.9%)
#   artisans,_commerçants,_chefs_d'entreprise
# chômeurs
# rp2016: 2744 (88.9%)
#   cadres_et_professions_intellectuelles_supérieures
# actifs_ayant_un_emploi
# rp2016: 2744 (88.9%)
#   cadres_et_professions_intellectuelles_supérieures
# chômeurs
# rp2016: 2744 (88.9%)
#   professions_intermédiaires
# actifs_ayant_un_emploi
# rp2016: 2744 (88.9%)
#   professions_intermédiaires
# chômeurs
# rp2016: 2744 (88.9%)
#   employés
# actifs_ayant_un_emploi
# rp2016: 2744 (88.9%)
#   employés
# chômeurs
# rp2016: 2744 (88.9%)
#   ouvriers
# actifs_ayant_un_emploi
# rp2016: 2744 (88.9%)
#   ouvriers
# chômeurs
# rp2016: 2744 (88.9%)
#   agriculteurs
# actifs_ayant_un_emploi
# rp2022: 2745 (88.9%)
#   agriculteurs
# chômeurs
# rp2022: 2745 (88.9%)
#   artisans,_commerçants,_chefs_d'entreprise
# actifs_ayant_un_emploi
# rp2022: 2745 (88.9%)
#   artisans,_commerçants,_chefs_d'entreprise
# chômeurs
# rp2022: 2745 (88.9%)
#   cadres_et_professions_intellectuelles_supérieures
# actifs_ayant_un_emploi
# rp2022: 2745 (88.9%)
#   cadres_et_professions_intellectuelles_supérieures
# chômeurs
# rp2022: 2745 (88.9%)
#   professions_intermédiaires
# actifs_ayant_un_emploi
# rp2022: 2745 (88.9%)
#   professions_intermédiaires
# chômeurs
# rp2022: 2745 (88.9%)
#   employés
# actifs_ayant_un_emploi
# rp2022: 2745 (88.9%)
#   employés
# chômeurs
# rp2022: 2745 (88.9%)
#   ouvriers
# actifs_ayant_un_emploi
# rp2022: 2745 (88.9%)
#   ouvriers
# chômeurs
# rp2022: 2745 (88.9%)
#
# csp_diplome (2744 lignes) — 777966 valeurs manquantes :
#   agriculteurs
# aucun_diplôme
# rp1968: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_cep
# rp1968: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_bepc
# rp1968: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_cap-bep
# rp1968: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_bac_général_ou_technique
# rp1968: 2401 (87.5%)
#   agriculteurs
# diplôme_supérieur_au_baccalauréat
# rp1968: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# aucun_diplôme
# rp1968: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_cep
# rp1968: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_bepc
# rp1968: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_cap-bep
# rp1968: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_bac_général_ou_technique
# rp1968: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_supérieur_au_baccalauréat
# rp1968: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# aucun_diplôme
# rp1968: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_cep
# rp1968: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_bepc
# rp1968: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_cap-bep
# rp1968: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_bac_général_ou_technique
# rp1968: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_supérieur_au_baccalauréat
# rp1968: 2401 (87.5%)
#   professions_intermédiaires
# aucun_diplôme
# rp1968: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_cep
# rp1968: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_bepc
# rp1968: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_cap-bep
# rp1968: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_bac_général_ou_technique
# rp1968: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_supérieur_au_baccalauréat
# rp1968: 2401 (87.5%)
#   employés
# aucun_diplôme
# rp1968: 2401 (87.5%)
#   employés
# diplôme_de_niveau_cep
# rp1968: 2401 (87.5%)
#   employés
# diplôme_de_niveau_bepc
# rp1968: 2401 (87.5%)
#   employés
# diplôme_de_niveau_cap-bep
# rp1968: 2401 (87.5%)
#   employés
# diplôme_de_niveau_bac_général_ou_technique
# rp1968: 2401 (87.5%)
#   employés
# diplôme_supérieur_au_baccalauréat
# rp1968: 2401 (87.5%)
#   ouvriers
# aucun_diplôme
# rp1968: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_cep
# rp1968: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_bepc
# rp1968: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_cap-bep
# rp1968: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_bac_général_ou_technique
# rp1968: 2401 (87.5%)
#   ouvriers
# diplôme_supérieur_au_baccalauréat
# rp1968: 2401 (87.5%)
#   agriculteurs
# aucun_diplôme
# rp1975: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_cep
# rp1975: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_bepc
# rp1975: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_cap-bep
# rp1975: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_bac_général_ou_technique
# rp1975: 2401 (87.5%)
#   agriculteurs
# diplôme_supérieur_au_baccalauréat
# rp1975: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# aucun_diplôme
# rp1975: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_cep
# rp1975: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_bepc
# rp1975: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_cap-bep
# rp1975: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_bac_général_ou_technique
# rp1975: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_supérieur_au_baccalauréat
# rp1975: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# aucun_diplôme
# rp1975: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_cep
# rp1975: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_bepc
# rp1975: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_cap-bep
# rp1975: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_bac_général_ou_technique
# rp1975: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_supérieur_au_baccalauréat
# rp1975: 2401 (87.5%)
#   professions_intermédiaires
# aucun_diplôme
# rp1975: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_cep
# rp1975: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_bepc
# rp1975: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_cap-bep
# rp1975: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_bac_général_ou_technique
# rp1975: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_supérieur_au_baccalauréat
# rp1975: 2401 (87.5%)
#   employés
# aucun_diplôme
# rp1975: 2401 (87.5%)
#   employés
# diplôme_de_niveau_cep
# rp1975: 2401 (87.5%)
#   employés
# diplôme_de_niveau_bepc
# rp1975: 2401 (87.5%)
#   employés
# diplôme_de_niveau_cap-bep
# rp1975: 2401 (87.5%)
#   employés
# diplôme_de_niveau_bac_général_ou_technique
# rp1975: 2401 (87.5%)
#   employés
# diplôme_supérieur_au_baccalauréat
# rp1975: 2401 (87.5%)
#   ouvriers
# aucun_diplôme
# rp1975: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_cep
# rp1975: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_bepc
# rp1975: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_cap-bep
# rp1975: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_bac_général_ou_technique
# rp1975: 2401 (87.5%)
#   ouvriers
# diplôme_supérieur_au_baccalauréat
# rp1975: 2401 (87.5%)
#   agriculteurs
# aucun_diplôme
# rp1982: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_cep
# rp1982: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_bepc
# rp1982: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_cap-bep
# rp1982: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_bac_général_ou_technique
# rp1982: 2401 (87.5%)
#   agriculteurs
# diplôme_universitaire_de_1er_cycle
# rp1982: 2401 (87.5%)
#   agriculteurs
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp1982: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# aucun_diplôme
# rp1982: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_cep
# rp1982: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_bepc
# rp1982: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_cap-bep
# rp1982: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_bac_général_ou_technique
# rp1982: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_universitaire_de_1er_cycle
# rp1982: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp1982: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# aucun_diplôme
# rp1982: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_cep
# rp1982: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_bepc
# rp1982: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_cap-bep
# rp1982: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_bac_général_ou_technique
# rp1982: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_universitaire_de_1er_cycle
# rp1982: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp1982: 2401 (87.5%)
#   professions_intermédiaires
# aucun_diplôme
# rp1982: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_cep
# rp1982: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_bepc
# rp1982: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_cap-bep
# rp1982: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_bac_général_ou_technique
# rp1982: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_universitaire_de_1er_cycle
# rp1982: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp1982: 2401 (87.5%)
#   employés
# aucun_diplôme
# rp1982: 2401 (87.5%)
#   employés
# diplôme_de_niveau_cep
# rp1982: 2401 (87.5%)
#   employés
# diplôme_de_niveau_bepc
# rp1982: 2401 (87.5%)
#   employés
# diplôme_de_niveau_cap-bep
# rp1982: 2401 (87.5%)
#   employés
# diplôme_de_niveau_bac_général_ou_technique
# rp1982: 2401 (87.5%)
#   employés
# diplôme_universitaire_de_1er_cycle
# rp1982: 2401 (87.5%)
#   employés
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp1982: 2401 (87.5%)
#   ouvriers
# aucun_diplôme
# rp1982: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_cep
# rp1982: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_bepc
# rp1982: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_cap-bep
# rp1982: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_bac_général_ou_technique
# rp1982: 2401 (87.5%)
#   ouvriers
# diplôme_universitaire_de_1er_cycle
# rp1982: 2401 (87.5%)
#   ouvriers
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp1982: 2401 (87.5%)
#   agriculteurs
# aucun_diplôme
# rp1990: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_cep
# rp1990: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_bepc
# rp1990: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_cap-bep
# rp1990: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_bac_général_ou_technique
# rp1990: 2401 (87.5%)
#   agriculteurs
# diplôme_universitaire_de_1er_cycle
# rp1990: 2401 (87.5%)
#   agriculteurs
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp1990: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# aucun_diplôme
# rp1990: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_cep
# rp1990: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_bepc
# rp1990: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_cap-bep
# rp1990: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_bac_général_ou_technique
# rp1990: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_universitaire_de_1er_cycle
# rp1990: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp1990: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# aucun_diplôme
# rp1990: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_cep
# rp1990: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_bepc
# rp1990: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_cap-bep
# rp1990: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_bac_général_ou_technique
# rp1990: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_universitaire_de_1er_cycle
# rp1990: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp1990: 2401 (87.5%)
#   professions_intermédiaires
# aucun_diplôme
# rp1990: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_cep
# rp1990: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_bepc
# rp1990: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_cap-bep
# rp1990: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_bac_général_ou_technique
# rp1990: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_universitaire_de_1er_cycle
# rp1990: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp1990: 2401 (87.5%)
#   employés
# aucun_diplôme
# rp1990: 2401 (87.5%)
#   employés
# diplôme_de_niveau_cep
# rp1990: 2401 (87.5%)
#   employés
# diplôme_de_niveau_bepc
# rp1990: 2401 (87.5%)
#   employés
# diplôme_de_niveau_cap-bep
# rp1990: 2401 (87.5%)
#   employés
# diplôme_de_niveau_bac_général_ou_technique
# rp1990: 2401 (87.5%)
#   employés
# diplôme_universitaire_de_1er_cycle
# rp1990: 2401 (87.5%)
#   employés
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp1990: 2401 (87.5%)
#   ouvriers
# aucun_diplôme
# rp1990: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_cep
# rp1990: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_bepc
# rp1990: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_cap-bep
# rp1990: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_bac_général_ou_technique
# rp1990: 2401 (87.5%)
#   ouvriers
# diplôme_universitaire_de_1er_cycle
# rp1990: 2401 (87.5%)
#   ouvriers
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp1990: 2401 (87.5%)
#   agriculteurs
# aucun_diplôme
# rp1999: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_cep
# rp1999: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_bepc
# rp1999: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_cap-bep
# rp1999: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_bac_général_ou_technique
# rp1999: 2401 (87.5%)
#   agriculteurs
# diplôme_universitaire_de_1er_cycle
# rp1999: 2401 (87.5%)
#   agriculteurs
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp1999: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# aucun_diplôme
# rp1999: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_cep
# rp1999: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_bepc
# rp1999: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_cap-bep
# rp1999: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_bac_général_ou_technique
# rp1999: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_universitaire_de_1er_cycle
# rp1999: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp1999: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# aucun_diplôme
# rp1999: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_cep
# rp1999: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_bepc
# rp1999: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_cap-bep
# rp1999: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_bac_général_ou_technique
# rp1999: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_universitaire_de_1er_cycle
# rp1999: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp1999: 2401 (87.5%)
#   professions_intermédiaires
# aucun_diplôme
# rp1999: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_cep
# rp1999: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_bepc
# rp1999: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_cap-bep
# rp1999: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_bac_général_ou_technique
# rp1999: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_universitaire_de_1er_cycle
# rp1999: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp1999: 2401 (87.5%)
#   employés
# aucun_diplôme
# rp1999: 2401 (87.5%)
#   employés
# diplôme_de_niveau_cep
# rp1999: 2401 (87.5%)
#   employés
# diplôme_de_niveau_bepc
# rp1999: 2401 (87.5%)
#   employés
# diplôme_de_niveau_cap-bep
# rp1999: 2401 (87.5%)
#   employés
# diplôme_de_niveau_bac_général_ou_technique
# rp1999: 2401 (87.5%)
#   employés
# diplôme_universitaire_de_1er_cycle
# rp1999: 2401 (87.5%)
#   employés
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp1999: 2401 (87.5%)
#   ouvriers
# aucun_diplôme
# rp1999: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_cep
# rp1999: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_bepc
# rp1999: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_cap-bep
# rp1999: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_bac_général_ou_technique
# rp1999: 2401 (87.5%)
#   ouvriers
# diplôme_universitaire_de_1er_cycle
# rp1999: 2401 (87.5%)
#   ouvriers
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp1999: 2401 (87.5%)
#   agriculteurs
# aucun_diplôme
# rp2006: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_cep
# rp2006: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_bepc
# rp2006: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_cap-bep
# rp2006: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_bac_général_ou_technique
# rp2006: 2401 (87.5%)
#   agriculteurs
# diplôme_universitaire_de_1er_cycle
# rp2006: 2401 (87.5%)
#   agriculteurs
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp2006: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# aucun_diplôme
# rp2006: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_cep
# rp2006: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_bepc
# rp2006: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_cap-bep
# rp2006: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_bac_général_ou_technique
# rp2006: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_universitaire_de_1er_cycle
# rp2006: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp2006: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# aucun_diplôme
# rp2006: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_cep
# rp2006: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_bepc
# rp2006: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_cap-bep
# rp2006: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_bac_général_ou_technique
# rp2006: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_universitaire_de_1er_cycle
# rp2006: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp2006: 2401 (87.5%)
#   professions_intermédiaires
# aucun_diplôme
# rp2006: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_cep
# rp2006: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_bepc
# rp2006: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_cap-bep
# rp2006: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_bac_général_ou_technique
# rp2006: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_universitaire_de_1er_cycle
# rp2006: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp2006: 2401 (87.5%)
#   employés
# aucun_diplôme
# rp2006: 2401 (87.5%)
#   employés
# diplôme_de_niveau_cep
# rp2006: 2401 (87.5%)
#   employés
# diplôme_de_niveau_bepc
# rp2006: 2401 (87.5%)
#   employés
# diplôme_de_niveau_cap-bep
# rp2006: 2401 (87.5%)
#   employés
# diplôme_de_niveau_bac_général_ou_technique
# rp2006: 2401 (87.5%)
#   employés
# diplôme_universitaire_de_1er_cycle
# rp2006: 2401 (87.5%)
#   employés
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp2006: 2401 (87.5%)
#   ouvriers
# aucun_diplôme
# rp2006: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_cep
# rp2006: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_bepc
# rp2006: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_cap-bep
# rp2006: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_bac_général_ou_technique
# rp2006: 2401 (87.5%)
#   ouvriers
# diplôme_universitaire_de_1er_cycle
# rp2006: 2401 (87.5%)
#   ouvriers
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp2006: 2401 (87.5%)
#   agriculteurs
# aucun_diplôme
# rp2011: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_cep
# rp2011: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_bepc
# rp2011: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_cap-bep
# rp2011: 2401 (87.5%)
#   agriculteurs
# diplôme_de_niveau_bac_général_ou_technique
# rp2011: 2401 (87.5%)
#   agriculteurs
# diplôme_universitaire_de_1er_cycle
# rp2011: 2401 (87.5%)
#   agriculteurs
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp2011: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# aucun_diplôme
# rp2011: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_cep
# rp2011: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_bepc
# rp2011: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_cap-bep
# rp2011: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_bac_général_ou_technique
# rp2011: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_universitaire_de_1er_cycle
# rp2011: 2401 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp2011: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# aucun_diplôme
# rp2011: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_cep
# rp2011: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_bepc
# rp2011: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_cap-bep
# rp2011: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_bac_général_ou_technique
# rp2011: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_universitaire_de_1er_cycle
# rp2011: 2401 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp2011: 2401 (87.5%)
#   professions_intermédiaires
# aucun_diplôme
# rp2011: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_cep
# rp2011: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_bepc
# rp2011: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_cap-bep
# rp2011: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_bac_général_ou_technique
# rp2011: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_universitaire_de_1er_cycle
# rp2011: 2401 (87.5%)
#   professions_intermédiaires
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp2011: 2401 (87.5%)
#   employés
# aucun_diplôme
# rp2011: 2401 (87.5%)
#   employés
# diplôme_de_niveau_cep
# rp2011: 2401 (87.5%)
#   employés
# diplôme_de_niveau_bepc
# rp2011: 2401 (87.5%)
#   employés
# diplôme_de_niveau_cap-bep
# rp2011: 2401 (87.5%)
#   employés
# diplôme_de_niveau_bac_général_ou_technique
# rp2011: 2401 (87.5%)
#   employés
# diplôme_universitaire_de_1er_cycle
# rp2011: 2401 (87.5%)
#   employés
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp2011: 2401 (87.5%)
#   ouvriers
# aucun_diplôme
# rp2011: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_cep
# rp2011: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_bepc
# rp2011: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_cap-bep
# rp2011: 2401 (87.5%)
#   ouvriers
# diplôme_de_niveau_bac_général_ou_technique
# rp2011: 2401 (87.5%)
#   ouvriers
# diplôme_universitaire_de_1er_cycle
# rp2011: 2401 (87.5%)
#   ouvriers
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp2011: 2401 (87.5%)
#   agriculteurs
# aucun_diplôme
# rp2022: 2402 (87.5%)
#   agriculteurs
# diplôme_de_niveau_cep
# rp2022: 2402 (87.5%)
#   agriculteurs
# diplôme_de_niveau_bepc
# rp2022: 2402 (87.5%)
#   agriculteurs
# diplôme_de_niveau_cap-bep
# rp2022: 2402 (87.5%)
#   agriculteurs
# diplôme_de_niveau_bac_général_ou_technique
# rp2022: 2402 (87.5%)
#   agriculteurs
# diplôme_universitaire_de_1er_cycle
# rp2022: 2402 (87.5%)
#   agriculteurs
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp2022: 2402 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# aucun_diplôme
# rp2022: 2402 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_cep
# rp2022: 2402 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_bepc
# rp2022: 2402 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_cap-bep
# rp2022: 2402 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_de_niveau_bac_général_ou_technique
# rp2022: 2402 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_universitaire_de_1er_cycle
# rp2022: 2402 (87.5%)
#   artisans,_commerçants,_chefs_d'entreprises
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp2022: 2402 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# aucun_diplôme
# rp2022: 2402 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_cep
# rp2022: 2402 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_bepc
# rp2022: 2402 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_cap-bep
# rp2022: 2402 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_de_niveau_bac_général_ou_technique
# rp2022: 2402 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_universitaire_de_1er_cycle
# rp2022: 2402 (87.5%)
#   cadres_et_professions_intellectuelles_supérieures
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp2022: 2402 (87.5%)
#   professions_intermédiaires
# aucun_diplôme
# rp2022: 2402 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_cep
# rp2022: 2402 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_bepc
# rp2022: 2402 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_cap-bep
# rp2022: 2402 (87.5%)
#   professions_intermédiaires
# diplôme_de_niveau_bac_général_ou_technique
# rp2022: 2402 (87.5%)
#   professions_intermédiaires
# diplôme_universitaire_de_1er_cycle
# rp2022: 2402 (87.5%)
#   professions_intermédiaires
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp2022: 2402 (87.5%)
#   employés
# aucun_diplôme
# rp2022: 2402 (87.5%)
#   employés
# diplôme_de_niveau_cep
# rp2022: 2402 (87.5%)
#   employés
# diplôme_de_niveau_bepc
# rp2022: 2402 (87.5%)
#   employés
# diplôme_de_niveau_cap-bep
# rp2022: 2402 (87.5%)
#   employés
# diplôme_de_niveau_bac_général_ou_technique
# rp2022: 2402 (87.5%)
#   employés
# diplôme_universitaire_de_1er_cycle
# rp2022: 2402 (87.5%)
#   employés
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp2022: 2402 (87.5%)
#   ouvriers
# aucun_diplôme
# rp2022: 2402 (87.5%)
#   ouvriers
# diplôme_de_niveau_cep
# rp2022: 2402 (87.5%)
#   ouvriers
# diplôme_de_niveau_bepc
# rp2022: 2402 (87.5%)
#   ouvriers
# diplôme_de_niveau_cap-bep
# rp2022: 2402 (87.5%)
#   ouvriers
# diplôme_de_niveau_bac_général_ou_technique
# rp2022: 2402 (87.5%)
#   ouvriers
# diplôme_universitaire_de_1er_cycle
# rp2022: 2402 (87.5%)
#   ouvriers
# diplôme_universitaire_de_2ème_ou_3ème_cycle
# rp2022: 2402 (87.5%)
# diplomes (341 lignes) — OK
#
# elections (19596 lignes) — 18211 valeurs manquantes :
#   pct_voix_exprimes: 18211 (92.9%)
# naissances_deces (5797 lignes) — OK
# population (12617 lignes) — OK
#
# revenus (342 lignes) — 10810 valeurs manquantes :
#   [disp]_nbre_de_menages_fiscaux: 23 (6.7%)
#   [disp]_nbre_de_personnes_dans_les_menages_fiscaux: 23 (6.7%)
#   [disp]_nbre_dunites_de_consommation_dans_les_menages_fiscaux: 23 (6.7%)
#   [disp]_1ᵉʳ_quartile_(€): 231 (67.5%)
#   [disp]_mediane_(€): 23 (6.7%)
#   [disp]_3ᵉ_quartile_(€): 231 (67.5%)
#   [disp]_ecart_interquartile_(€): 231 (67.5%)
#   [disp]_1ᵉʳ_decile_(€): 231 (67.5%)
#   [disp]_2ᵉ_decile_(€): 231 (67.5%)
#   [disp]3ᵉ_decile_(€): 231 (67.5%)
#   [disp]_4ᵉ_decile_(€): 231 (67.5%)
#   [disp]_6ᵉ_decile_(€): 231 (67.5%)
#   [disp]_7ᵉ_decile_(€): 231 (67.5%)
#   [disp]_8ᵉ_decile_(€): 231 (67.5%)
#   [disp]_9ᵉ_decile_(€): 231 (67.5%)
#   [disp]_rapport_interdecile_9ᵉ_decile/1ᵉʳ_decile: 231 (67.5%)
#   [disp]_s80/20: 231 (67.5%)
#   [disp]_iice_de_gini: 231 (67.5%)
#   [disp]_part_des_revenus_d’activite_(%): 231 (67.5%)
#   [disp]_dont_part_des_salaires_et_traitements(%): 231 (67.5%)
#   [disp]_dont_part_des_iemnites_de_chômage_(%): 231 (67.5%)
#   [disp]_dont_part_des_revenus_des_activites_non_salariees_(%): 231 (67.5%)
#   [disp]_part_des_pensions,_retraites_et_rentes_(%): 231 (67.5%)
#   [disp]_part_des_revenus_du_patrimoine_et_autres_revenus_(%): 231 (67.5%)
#   [disp]_part_de_lensemble_des_prestations_sociales_(%): 231 (67.5%)
#   [disp]_dont_part_des_prestations_familiales_(%): 231 (67.5%)
#   [disp]_dont_part_des_minima_sociaux_(%): 231 (67.5%)
#   [disp]_dont_part_des_prestations_logement_(%): 231 (67.5%)
#   [disp]_part_des_impôts_(%): 231 (67.5%)
#   [dec]_nbre_de_menages_fiscaux: 23 (6.7%)
#   [dec]_nbre_de_personnes_dans_les_menages_fiscaux: 23 (6.7%)
#   [dec]_nbre_dunites_de_consommation_dans_les_menages_fiscaux: 23 (6.7%)
#   [dec]_part_des_menages_fiscaux_imposes_(%): 231 (67.5%)
#   [dec]_1ᵉʳ_quartile_(€): 231 (67.5%)
#   [dec]_mediane_(€): 23 (6.7%)
#   [dec]_3ᵉ_quartile_(€): 231 (67.5%)
#   [dec]_ecart_interquartile_(€): 231 (67.5%)
#   [dec]_1ᵉʳ_decile_(€): 231 (67.5%)
#   [dec]_2ᵉ_decile_(€): 231 (67.5%)
#   [dec]_3ᵉ_decile__(€): 231 (67.5%)
#   [dec]_4ᵉ_decile_(€): 231 (67.5%)
#   [dec]_6ᵉ_decile_(€): 231 (67.5%)
#   [dec]_7ᵉ_decile_(€): 231 (67.5%)
#   [dec]_8ᵉ_decile_(€): 231 (67.5%)
#   [dec]_9ᵉ_decile_(€): 231 (67.5%)
#   [dec]_rapport_interdecile_d9/d1: 231 (67.5%)
#   [dec]_s80/s20: 231 (67.5%)
#   [dec]_iice_de_gini: 231 (67.5%)
#   [dec]_part_des_revenus_d’activite_(%): 231 (67.5%)
#   [dec]_dont_part_des_salaires_et_traitements_(%): 231 (67.5%)
#   [dec]_dont_part_des_iemnites_de_chômage_(%): 231 (67.5%)
#   [dec]_dont_part_des_revenus_des_activites_non_salariees_(%): 231 (67.5%)
#   [dec]_part_des_pensions,_retraites_et_rentes_(%): 231 (67.5%)
#   [dec]_part_des_autres_revenus_(%): 231 (67.5%)
# risques (3184 lignes) — OK
#
# secteurs_activite (3087 lignes) — 197576 valeurs manquantes :
#   agriculture
# hommes
# rp1968: 2744 (88.9%)
#   agriculture
# femmes
# rp1968: 2744 (88.9%)
#   industrie
# hommes
# rp1968: 2744 (88.9%)
#   industrie
# femmes
# rp1968: 2744 (88.9%)
#   bâtiment_et_travaux_publics
# hommes
# rp1968: 2744 (88.9%)
#   bâtiment_et_travaux_publics
# femmes
# rp1968: 2744 (88.9%)
#   tertiaire
# hommes
# rp1968: 2744 (88.9%)
#   tertiaire
# femmes
# rp1968: 2744 (88.9%)
#   agriculture
# hommes
# rp1975: 2744 (88.9%)
#   agriculture
# femmes
# rp1975: 2744 (88.9%)
#   industrie
# hommes
# rp1975: 2744 (88.9%)
#   industrie
# femmes
# rp1975: 2744 (88.9%)
#   bâtiment_et_travaux_publics
# hommes
# rp1975: 2744 (88.9%)
#   bâtiment_et_travaux_publics
# femmes
# rp1975: 2744 (88.9%)
#   tertiaire
# hommes
# rp1975: 2744 (88.9%)
#   tertiaire
# femmes
# rp1975: 2744 (88.9%)
#   agriculture
# hommes
# rp1982: 2744 (88.9%)
#   agriculture
# femmes
# rp1982: 2744 (88.9%)
#   industrie
# hommes
# rp1982: 2744 (88.9%)
#   industrie
# femmes
# rp1982: 2744 (88.9%)
#   bâtiment_et_travaux_publics
# hommes
# rp1982: 2744 (88.9%)
#   bâtiment_et_travaux_publics
# femmes
# rp1982: 2744 (88.9%)
#   tertiaire
# hommes
# rp1982: 2744 (88.9%)
#   tertiaire
# femmes
# rp1982: 2744 (88.9%)
#   agriculture
# hommes
# rp1990: 2744 (88.9%)
#   agriculture
# femmes
# rp1990: 2744 (88.9%)
#   industrie
# hommes
# rp1990: 2744 (88.9%)
#   industrie
# femmes
# rp1990: 2744 (88.9%)
#   bâtiment_et_travaux_publics
# hommes
# rp1990: 2744 (88.9%)
#   bâtiment_et_travaux_publics
# femmes
# rp1990: 2744 (88.9%)
#   tertiaire
# hommes
# rp1990: 2744 (88.9%)
#   tertiaire
# femmes
# rp1990: 2744 (88.9%)
#   agriculture
# hommes
# rp1999: 2744 (88.9%)
#   agriculture
# femmes
# rp1999: 2744 (88.9%)
#   industrie
# hommes
# rp1999: 2744 (88.9%)
#   industrie
# femmes
# rp1999: 2744 (88.9%)
#   bâtiment_et_travaux_publics
# hommes
# rp1999: 2744 (88.9%)
#   bâtiment_et_travaux_publics
# femmes
# rp1999: 2744 (88.9%)
#   tertiaire
# hommes
# rp1999: 2744 (88.9%)
#   tertiaire
# femmes
# rp1999: 2744 (88.9%)
#   agriculture
# hommes
# rp2006: 2744 (88.9%)
#   agriculture
# femmes
# rp2006: 2744 (88.9%)
#   industrie
# hommes
# rp2006: 2744 (88.9%)
#   industrie
# femmes
# rp2006: 2744 (88.9%)
#   bâtiment_et_travaux_publics
# hommes
# rp2006: 2744 (88.9%)
#   bâtiment_et_travaux_publics
# femmes
# rp2006: 2744 (88.9%)
#   tertiaire
# hommes
# rp2006: 2744 (88.9%)
#   tertiaire
# femmes
# rp2006: 2744 (88.9%)
#   agriculture
# hommes
# rp2011: 2744 (88.9%)
#   agriculture
# femmes
# rp2011: 2744 (88.9%)
#   industrie
# hommes
# rp2011: 2744 (88.9%)
#   industrie
# femmes
# rp2011: 2744 (88.9%)
#   bâtiment_et_travaux_publics
# hommes
# rp2011: 2744 (88.9%)
#   bâtiment_et_travaux_publics
# femmes
# rp2011: 2744 (88.9%)
#   tertiaire
# hommes
# rp2011: 2744 (88.9%)
#   tertiaire
# femmes
# rp2011: 2744 (88.9%)
#   agriculture
# hommes
# rp2016: 2744 (88.9%)
#   agriculture
# femmes
# rp2016: 2744 (88.9%)
#   industrie
# hommes
# rp2016: 2744 (88.9%)
#   industrie
# femmes
# rp2016: 2744 (88.9%)
#   bâtiment_et_travaux_publics
# hommes
# rp2016: 2744 (88.9%)
#   bâtiment_et_travaux_publics
# femmes
# rp2016: 2744 (88.9%)
#   tertiaire
# hommes
# rp2016: 2744 (88.9%)
#   tertiaire
# femmes
# rp2016: 2744 (88.9%)
#   agriculture
# hommes
# rp2022: 2745 (88.9%)
#   agriculture
# femmes
# rp2022: 2745 (88.9%)
#   industrie
# hommes
# rp2022: 2745 (88.9%)
#   industrie
# femmes
# rp2022: 2745 (88.9%)
#   bâtiment_et_travaux_publics
# hommes
# rp2022: 2745 (88.9%)
#   bâtiment_et_travaux_publics
# femmes
# rp2022: 2745 (88.9%)
#   tertiaire
# hommes
# rp2022: 2745 (88.9%)
#   tertiaire
# femmes
# rp2022: 2745 (88.9%)

# %%
# Vérifier la couverture des jointures : combien de communes ont des données dans chaque table
codgeo_communes = set(communes['codgeo'])
tables_avec_codgeo = ['elections', 'population', 'revenus', 'csp', 'diplomes',
                       'comptes_communes', 'catnat', 'naissances_deces']

print(f"Communes de référence : {len(codgeo_communes)}")
print(f"\n{'Table':<25s} {'Communes':>10s} {'Couverture':>12s}")
print("-" * 50)
for table in tables_avec_codgeo:
    try:
        codgeos = set(pd.read_sql(f"SELECT DISTINCT codgeo FROM {table}", conn)['codgeo'])
        inter = codgeos & codgeo_communes
        pct = 100 * len(inter) / len(codgeo_communes)
        print(f"  {table:<23s} {len(inter):>8d}   {pct:>8.1f}%")
    except Exception as e:
        print(f"  {table:<23s} Erreur: {e}")
# Out:
# Communes de référence : 341
#
# Table                       Communes   Couverture
# --------------------------------------------------
#   elections                    341      100.0%
#   population                   341      100.0%
#   revenus                      341      100.0%
#   csp                          341      100.0%
#   diplomes                     341      100.0%
#   comptes_communes             341      100.0%
#   catnat                       341      100.0%
#   naissances_deces             341      100.0%

# %%
conn.close()
print("Connexion fermée.")
# Out:
# Connexion fermée.
